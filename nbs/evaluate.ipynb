# %%
# %load_ext autoreload
# %autoreload 2

# %%
from hackathon.data import register_dataset
from hackathon.evaluate import get_model_for_eval, evaluate_coco_dataset

# %%
cfg = get_model_for_eval("frcnn-bfish", "../models/",  device="cpu")
# Out:
# [12/03 19:22:21 detectron2]: Rank of current process: 0. World size: 1
# No CUDA runtime is found, using CUDA_HOME='/usr/local/cuda'
# [12/03 19:22:22 detectron2]: Environment info:
# ---------------------  -------------------------------------------------------------------------------------
# sys.platform           linux
# Python                 3.7.9 (default, Aug 31 2020, 12:42:55) [GCC 7.3.0]
# numpy                  1.19.4
# detectron2             0.2.1 @/home/ubuntu/anaconda3/envs/noaa/lib/python3.7/site-packages/detectron2
# Compiler               GCC 7.3
# CUDA compiler          CUDA 10.1
# DETECTRON2_ENV_MODULE  <not set>
# PyTorch                1.6.0+cu101 @/home/ubuntu/anaconda3/envs/noaa/lib/python3.7/site-packages/torch
# PyTorch debug build    False
# GPU available          False
# Pillow                 8.0.1
# torchvision            0.7.0+cu101 @/home/ubuntu/anaconda3/envs/noaa/lib/python3.7/site-packages/torchvision
# fvcore                 0.1.2.post20200910
# ...

# %%
register_dataset("lehi1", "../data/")
evaluate_coco_dataset(cfg, "lehi1")
# Out:
# [12/03 19:22:23 fvcore.common.checkpoint]: Loading checkpoint from ../models/frcnn-bfish/model_0005159.pth
# [12/03 19:22:23 d2.data.datasets.coco]: Loaded 371 images in COCO format from ../data/Lehi1/Lehi1_coco.json
# [12/03 19:22:23 d2.data.build]: Distribution of instances among all 1 categories:
# |  category  | #instances   |
# |:----------:|:-------------|
# |    FISH    | 2499         |
# |            |              |
# [12/03 19:22:23 d2.data.common]: Serializing 371 elements to byte tensors and concatenating them all ...
# [12/03 19:22:23 d2.data.common]: Serialized dataset takes 0.16 MiB
# [12/03 19:22:23 d2.data.dataset_mapper]: Augmentations used in training: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [12/03 19:22:23 d2.evaluation.evaluator]: Start inference on 371 images
# /home/ubuntu/anaconda3/envs/noaa/lib/python3.7/site-packages/detectron2/layers/wrappers.py:226: UserWarning: This overload of nonzero is deprecated:
# ...

# %%
# see how well a just-fishnet model works....it doesn't
cfg = get_model_for_eval("frcnn-fishnet", "../models/")
evaluate_coco_dataset(cfg, "lehi1")
